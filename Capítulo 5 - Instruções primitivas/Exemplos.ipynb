# %% [markdown]
# # Exemplos de funções matemáticas em Python

# %%
import math

# %%
# Retorna o valor absoluto de uma expressão
print(math.fabs(-10))
# Out:
# 10.0

# %%
# Retorna o arco de tangente do argumento utilizado
print(math.atan(10))
# Out:
# 1.4711276743037347

# %%
# Retorna o valor do co-seno
print(math.cos(10))
# Out:
# -0.8390715290764524

# %%
# Retorna o valor exponencial
print(math.exp(10))
# Out:
# 22026.465794806718

# %%
# Retorna a parte fracionária e inteira de uma expressão
print(math.modf(10.5))

print("Valor fracionário: ", math.modf(10.5)[0])
print("Valor inteiro: ", math.modf(10.5)[1])
# Out:
# (0.5, 10.0)
# Valor fracionário:  0.5
# Valor inteiro:  10.0

# %%
# Retorna com a parte fracionária removida, deixando a parte inteira.
print(math.trunc(10.5))
# Out:
# 10

# %%
# Retorna o logaritmo natural
print(math.log(10))
# Out:
# 2.302585092994046

# %%
# Retorna o valor de PI
print(math.pi)
# Out:
# 3.141592653589793

# %%
# Retorna o valor do seno
print(math.sin(10))
# Out:
# -0.5440211108893698

# %%
# Retorna o parâmetro elevado ao quadrado.
print(math.pow(10, 2))
# Out:
# 100.0

# %%
# Retorna a raiz quadrada
print(math.sqrt(10))
# Out:
# 3.1622776601683795
